# %%
import llika
import imp  
imp.reload(llika)
import networkx as nx
from sklearn import datasets
iris = datasets.load_iris()

# %%
ll = llika.Llika()

# %%
ll.setSettings(knn=12)
g=ll.buildNetwork(iris.data,iris.target)
ll.drawGraph(g,"GRAPH KNN")

# %%
ll.insertNode(g,iris.data[1,:])

# %%
ll.drawGraph(g,"GRAPH KNN")
